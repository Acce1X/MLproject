# %%
# -*- coding: UTF-8 -*-
import pandas as pd 
import jieba 
import jieba.analyse
from collections import Counter
df = pd.read_csv("data.csv",header=0,encoding='utf-8',dtype = str)
#df.head(5)

# %%
df = df.drop(['Id','过敏史','希望得到的帮助','患病时长','就诊科室','用药情况','链接','既往史','疾病分类'],axis = 1)
df.head(5)
# Out:
#                          标题                  疾病  \
# 0   胆汁反流性胃炎，胸口堵的疼，嗳气，呕吐怎么办？  胆汁反流性胃炎，胸口堵的厉害，嗳气。
# 1                   慢性胃炎，嗳气               胃疼，嗳气
# 2                 胃窦慢性萎缩性胃炎           胃窦慢性萎缩性胃炎
# 3               混合痔与肠胃炎治疗咨询                 混合痔
# 4             慢性浅表性胃炎该如何调理？             慢性浅表性胃炎
#
#                                                 病情描述
# 0  倪主任您好，我今年三月查出胆汁反流，吃了两个多月中药和奥美拉错，莫沙必利，没有多大效果，之后...
# 1  一个月前查过幽门螺杆菌，3+，后来吃了阿奇霉素，阿莫西林，尿囊素，雷贝拉唑，吃了一半感觉胃疼...
# 2  2014年2月胃痛，2014年5月19日在保定二五二医院做胃镜，病理诊断胃窦慢性萎缩性胃炎伴...
# 3  李医生，您好！我是1月底肠胃炎后，大便稀，后来发现痔疮脱出越来越明显，便时有鲜血。医院看后，...
# 4  检查及化验：患胃病二年多了，刚开始是幽门管糜烂性炎，现在是慢性浅表性胃炎。治疗情况（当前用药...

# %%
test = df.head(5)

stopwords = [line.strip() for line in open('stopwords.txt'encoding='UTF-8').readlines()]

freq_list = Counter()
for index,row in test.iterrows():
    words = []
    for col in row:
        words = jieba.cut(str(col),cut_all = False)
        for word in words:
            if word not in 

    #print("Default Mode: " + "/ ".join(seg_list))
    content += seg_list

# %% [markdown]
# row是一个series变量（name+context）
# 忽略疾病的描述

# %%
jieba.analyse.set_stop_words('./stopwords/哈工大停用词表.txt') 
tags = jieba.analyse.extract_tags(str(content), topK=20)
print(",".join(tags))
# Out:
# 胃炎,慢性,肠胃炎,浅表性,胃镜,胃癌,萎缩性,大便,糜烂,医生,治疗,感觉,检查,nan,急性,胆汁,幽门,医院,胃窦,胃胀
